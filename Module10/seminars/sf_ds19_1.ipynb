# %% [markdown]
# # Программирование на языке Python
# ## Семинар 19. Работа с файлами разных форматов
#
# https://historik.val.se/val/val2018/slutresultat/R/rike/index.html

# %% [markdown]
# **Жирный текст**
#
# <b>Жирный текст</b>
#
# <p>
#     Текст<br>пункт 1,<br><u style="color: red;">
#         пункт 2
#     </u>
# </p>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th>Заголовок 1</th>
#             <th>Заголовок 2</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="background-color: hotpink;">Ячейка 1.1</td>
#             <td>Ячейка 2.1</td>
#         </tr>
#         <tr>
#             <td>Ячейка 2.1</td>
#             <td>Ячейка 2.2</td>
#         </tr>
#     </tbody>
# </table>

# %%
import requests
from bs4 import BeautifulSoup, Tag

import numpy as np
import pandas as pd

# %%
# url = 'https://historik.val.se/val/val2018/slutresultat/R/kommun/10/82/index.html'
url = 'https://historik.val.se/val/val2018/slutresultat/R/rike/index.html'

page = requests.get(url)
page_text = page.content.decode()
soup = BeautifulSoup(page_text)

page.close()

# %%
nt = get_navigation_table(soup)

# %%
nt_gen = parse_navigation_table(nt)

# %%
nt_iter = iter(nt_gen)

# %%
check[2].a.get('href')
# Out:
# '../../../../../slutresultat/R/kommun/10/82/index.html'

# %%
h2 = soup.find('h2', {'id': ''})

# %%
import requests
from bs4 import BeautifulSoup, Tag
from warnings import warn


INDICES = {0, 1, 2, 6}
MINLEVELS = {'valdistrikt', 'onsdagsdistrikt'}
MAIN_TABLE_CLASS = 'sorteringsbar_tabell'
NAVIGATION_TABLE_ID = 'oversiktstabell'
URL = 'https://historik.val.se/val/val2018/slutresultat/R'


def get_table(page: BeautifulSoup) -> Tag:
    table = page.find('table', {'class': MAIN_TABLE_CLASS})

    return table


def parse_table(table: Tag) -> dict:
    # extract headers
    keys = [th.text for index, th in enumerate(table.find_all('th')) if index in INDICES]

    # extract values
    rows = table.find_all('tr')[1:]
    rows_text = [[td.text for index, td in enumerate(row.find_all('td')) if index in INDICES] for row in rows]

    # get dict
    table_dict = dict(zip(keys, zip(*rows_text)))

    return table_dict


def get_page(url: str) -> BeautifulSoup:
    response = requests.get(url)
    status_code = response.status_code

    if status_code == 200:
        # get content
        content = response.content.decode()  # response.text
    
        # parse content
        page = BeautifulSoup(content)
    else:
        warn(f'Page for url {url} not parsed, status code is {status_code}, returning None')
        page = None

    response.close()

    return page


def get_navigation_table(page: BeautifulSoup) -> Tag:
    navigation_table = page.find('table', {'id': NAVIGATION_TABLE_ID})

    return navigation_table


def parse_navigation_table(navigation_table: Tag):
    tds = navigation_table.find_all('td')
    active_index = [index for index, td in enumerate(tds) if td.get('class') == ['aktiv']][0]

    for td in tds[(active_index + 1):]:
        a = td.a
        
        # get level
        level = td.parent.get('class')[0]

        # get district
        district = a.text

        # get page
        href = a.get('href')
        url = f'{URL}/{href[(href.find("R") + 2):]}'
        page = get_page(url)

        if page is None:
            continue

        yield level, district, page


def parse_page(page: BeautifulSoup, districts=[]):
    navigation_table = get_navigation_table(page)
    navigation_table_parsed = parse_navigation_table(navigation_table)
    indent = '\t' * len(districts)

    for level, district, page in navigation_table_parsed:
        if level in MINLEVELS:
            table = get_table(page)
            table_parsed = parse_table(table)
            TABLES.append((districts + [(level, district)], table_parsed))

            print(f'{indent}({level}) {district} table parsed successfully...')
        else:
            print(f'{indent}({level}) {district}')
            parse_page(page, districts + [(level, district)])

# %%
url_main = 'https://historik.val.se/val/val2018/slutresultat/R/rike/index.html'
page = get_page(url_main)

TABLES = []
parse_page(page)
# Out:
# (riksdagsvalkrets) Blekinge län
# 	(kommun) Karlshamn
# 		(valdistrikt) Centrala Asarum table parsed successfully...
# 		(valdistrikt) Froarp table parsed successfully...
# 		(valdistrikt) Gustavstorp table parsed successfully...
# 		(valdistrikt) Horsaryd table parsed successfully...
# 		(valdistrikt) Hällaryd table parsed successfully...
# 		(valdistrikt) Högadal table parsed successfully...
# 		(valdistrikt) Korpadalen table parsed successfully...
# 		(valdistrikt) Mörrum västra table parsed successfully...
# 		(valdistrikt) Mörrum östra table parsed successfully...
# 		(valdistrikt) Prästslätten table parsed successfully...
# 		(valdistrikt) Skogsborg table parsed successfully...
# 		(valdistrikt) Stadsporten table parsed successfully...
# 		(valdistrikt) Svängsta nordöst table parsed successfully...
# 		(valdistrikt) Svängsta sydväst table parsed successfully...
# 		(valdistrikt) Torget table parsed successfully...
# 		(valdistrikt) Tubbaryd table parsed successfully...
# 		(valdistrikt) Vägga table parsed successfully...
# 		(valdistrikt) Österslätt table parsed successfully...
# 		(onsdagsdistrikt) I vallokal ej räknade röster table parsed successfully...
# 	(kommun) Karlskrona
# 		(kommunvalkrets) Karlskrona C
# 			(valdistrikt) Aspö table parsed successfully...
# 			(valdistrikt) Bergåsa m.fl. table parsed successfully...
# 			(valdistrikt) Galgamarken table parsed successfully...
# 			(valdistrikt) Hogland m.fl. table parsed successfully...
# 			(valdistrikt) Hästö table parsed successfully...
# 			(valdistrikt) Långö-Gräsvik table parsed successfully...
# 			(valdistrikt) Möllebacken m.fl. table parsed successfully...
# 			(valdistrikt) Pantarholmen table parsed successfully...
# 			(valdistrikt) Rosenfeldt m.fl. table parsed successfully...
# 			(valdistrikt) Saltö-Björkholmen table parsed successfully...
# 			(valdistrikt) Trossö Ö table parsed successfully...
# 			(valdistrikt) Västerudd table parsed successfully...
# 			(valdistrikt) Wachtmeister m.fl. table parsed successfully...
# 			(onsdagsdistrikt) I vallokal ej räknade röster table parsed successfully...
# 		(kommunvalkrets) Karlskrona V
# 			(valdistrikt) Fridlevstad table parsed successfully...
# 			(valdistrikt) Hasslö table parsed successfully...
# 			(valdistrikt) Kungsmarken table parsed successfully...
# 			(valdistrikt) Marieberg m.fl. table parsed successfully...
# 			(valdistrikt) Mariedal-Backabo table parsed successfully...
# 			(valdistrikt) Nättraby S table parsed successfully...
# 			(valdistrikt) Nättraby V table parsed successfully...
# 			(valdistrikt) Nättraby Ö table parsed successfully...
# 			(valdistrikt) Rödeby N table parsed successfully...
# 			(valdistrikt) Rödeby S table parsed successfully...
# 			(valdistrikt) Sillhövda table parsed successfully...
# 			(valdistrikt) Strömsberg table parsed successfully...
# 			(valdistrikt) Tving table parsed successfully...
# 			(onsdagsdistrikt) I vallokal ej räknade röster table parsed successfully...
# 		(kommunvalkrets) Karlskrona Ö
# 			(valdistrikt) Jämjö N table parsed successfully...
# 			(valdistrikt) Jämjö S table parsed successfully...
# 			(valdistrikt) Kristianopel table parsed successfully...
# 			(valdistrikt) Kronotorp m.fl. table parsed successfully...
# 			(valdistrikt) Kättilsmåla table parsed successfully...
# 			(valdistrikt) Lyckeby V table parsed successfully...
# 			(valdistrikt) Lyckeby Ö table parsed successfully...
# 			(valdistrikt) Ramdala table parsed successfully...
# 			(valdistrikt) Spandelstorp m.fl. table parsed successfully...
# 			(valdistrikt) Sturkö table parsed successfully...
# 			(valdistrikt) Torhamn table parsed successfully...
# 			(valdistrikt) Torskors-Hässlegården table parsed successfully...
# 			(valdistrikt) Verkö m.fl. table parsed successfully...
# 			(onsdagsdistrikt) I vallokal ej räknade röster table parsed successfully...
# 	(kommun) Olofström
# 		(valdistrikt) Brännaregården-Gränum norra table parsed successfully...
# 		(valdistrikt) Ekeryd table parsed successfully...
# 		(valdistrikt) Jämshög-Gränum södra table parsed successfully...
# 		(valdistrikt) Kyrkhult-Hemsjö table parsed successfully...
# 		(valdistrikt) Oredslund table parsed successfully...
# 		(valdistrikt) Petrefors table parsed successfully...
# 		(valdistrikt) Vilboken-Vilshult table parsed successfully...
# 		(onsdagsdistrikt) I vallokal ej räknade röster table parsed successfully...
# 	(kommun) Ronneby
# 		(valdistrikt) Backaryd-Öljehult table parsed successfully...
# 		(valdistrikt) Blekan table parsed successfully...
# 		(valdistrikt) Bräkne-Hoby Landsbygd table parsed successfully...
# 		(valdistrikt) Bräkne-Hoby Samhälle table parsed successfully...
# 		(valdistrikt) Centrum table parsed successfully...
# 		(valdistrikt) Espedalen table parsed successfully...
# 		(valdistrikt) Fredriksberg table parsed successfully...
# 		(valdistrikt) Förkärla-Listerby N table parsed successfully...
# 		(valdistrikt) Hasselstad-Eringsboda table parsed successfully...
# 		(valdistrikt) Hjortsberga-Edestad table parsed successfully...
# 		(valdistrikt) Hulta table parsed successfully...
# 		(valdistrikt) Häggatorp table parsed successfully...
# 		(valdistrikt) Kalleberga table parsed successfully...
# 		(valdistrikt) Kallinge table parsed successfully...
# 		(valdistrikt) Listerby S table parsed successfully...
# 		(valdistrikt) Lugnet table parsed successfully...
# 		(valdistrikt) Persborg table parsed successfully...
# 		(valdistrikt) Varan table parsed successfully...
# 		(valdistrikt) Älgbacken table parsed successfully...
# 		(onsdagsdistrikt) I vallokal ej räknade röster table parsed successfully...
# 	(kommun) Sölvesborg
# 		(valdistrikt) Falkvik table parsed successfully...
# 		(valdistrikt) Furulund table parsed successfully...
# 		(valdistrikt) Gammalstorp m fl table parsed successfully...
# 		(valdistrikt) Hjortakroken table parsed successfully...
# 		(valdistrikt) Hällevik m fl table parsed successfully...
# 		(valdistrikt) Hörvik m fl table parsed successfully...
# 		(valdistrikt) Mjällby m fl table parsed successfully...
# 		(valdistrikt) Möllebacken table parsed successfully...
# 		(valdistrikt) Norje m fl table parsed successfully...
# 		(valdistrikt) Siretorp m fl table parsed successfully...
# 		(onsdagsdistrikt) I vallokal ej räknade röster table parsed successfully...
# (riksdagsvalkrets) Dalarnas län
# 	(kommun) Avesta
# 		(valdistrikt) Avesta C table parsed successfully...
# 		(valdistrikt) Avesta N-Högbo table parsed successfully...
# 		(valdistrikt) Avesta S table parsed successfully...
# 		(valdistrikt) Avesta V-Bengtsbo-Nyhyttan table parsed successfully...
# 		(valdistrikt) By table parsed successfully...
# 		(valdistrikt) Folkärna table parsed successfully...
# 		(valdistrikt) Fors table parsed successfully...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 page = get_page(url_main)
#       4 TABLES = []
# ----> 5 parse_page(page)
#
# Cell In[3], line 96, in parse_page(page, districts)
#      94 else:
#      95     print(f'{indent}({level}) {district}')
# ---> 96     parse_page(page, districts + [district])
#
# Cell In[3], line 96, in parse_page(page, districts)
#      94 else:
#      95     print(f'{indent}({level}) {district}')
# ---> 96     parse_page(page, districts + [district])
#
# Cell In[3], line 87, in parse_page(page, districts)
#      84 navigation_table_parsed = parse_navigation_table(navigation_table)
#      85 indent = '\t' * len(districts)
# ---> 87 for level, district, page in navigation_table_parsed:
#      88     if level in MINLEVELS:
#      89         table = get_table(page)
#
# Cell In[3], line 74, in parse_navigation_table(navigation_table)
#      72 href = a.get('href')
#      73 url = f'{URL}/{href[(href.find("R") + 2):]}'
# ---> 74 page = get_page(url)
#      76 if page is None:
#      77     continue
#
# Cell In[3], line 34, in get_page(url)
#      33 def get_page(url: str) -> BeautifulSoup:
# ---> 34     response = requests.get(url)
#      35     status_code = response.status_code
#      37     if status_code == 200:
#      38         # get content
#
# File ~/teaching/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/teaching/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/teaching/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/teaching/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/teaching/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/teaching/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File ~/teaching/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/teaching/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pickle

with open('tmp/tables.pickle', 'rb') as infile:
    TABLES = pickle.load(infile)

# %%
import numpy as np
import pandas as pd

def process_value_pd(table_dict) -> pd.DataFrame:
    table_df = pd.DataFrame(table_dict)

    return table_df

def process_value_np(table_dict) -> np.ndarray:
    table_np = np.array(list(table_dict.values()))

    return table_np

# %%
# %%timeit

values_df = pd.concat([process_value_pd(item[-1]) for item in TABLES])
# Out:
# 320 ms ± 2.79 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

values_nps = [process_value_np(item[-1]) for item in TABLES]
values_df2 = pd.DataFrame(np.hstack(values_nps).T, columns=['Förk.', 'Parti', 'Antal2018', 'Antal2014'])
# Out:
# 72.8 ms ± 227 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
pd.DataFrame(np.hstack(values_nps).T)
# Out:
#             0                                       1    2    3
# 0           M                             Moderaterna  162  164
# 1           C                           Centerpartiet   37   28
# 2           L      Liberalerna (tidigare Folkpartiet)   37   19
# 3          KD                       Kristdemokraterna   53   29
# 4           S      Arbetarepartiet-Socialdemokraterna  519  604
# ...       ...                                     ...  ...  ...
# 100553    ÖVR                  Övriga anmälda partier    7    6
# 100554                                 Giltiga röster  359  219
# 100555   OGEJ  Ogiltiga röster - inte anmälda partier
# 100556  BLANK                Ogiltiga röster - blanka    1    2
# 100557     OG                Ogiltiga röster - övriga
#
# [100558 rows x 4 columns]

# %%
values_nps
# Out:
# [array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['162', '37', '37', '53', '519', '82', '32', '311', '8', '11',
#          '1252', '\xa0', '13', '\xa0', '1265', '1555'],
#         ['164', '28', '19', '29', '604', '60', '54', '217', '19', '6',
#          '1200', '\xa0', '10', '\xa0', '1210', '1491']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['258', '97', '40', '62', '465', '85', '52', '420', '8', '11',
#          '1498', '\xa0', '7', '1', '1506', '1699'],
#         ['260', '78', '41', '39', '549', '74', '107', '326', '27', '11',
#          '1512', '\xa0', '14', '\xa0', '1526', '1716']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['111', '57', '30', '52', '334', '37', '18', '285', '1', '10',
#          '935', '1', '7', '2', '945', '1124'],
#         ['118', '41', '24', '31', '381', '37', '34', '218', '15', '4',
#          '903', '\xa0', '8', '\xa0', '911', '1102']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['224', '87', '41', '70', '498', '86', '51', '397', '6', '12',
#          '1472', '\xa0', '18', '\xa0', '1490', '1729'],
#         ['250', '62', '25', '41', '601', '74', '54', '293', '16', '10',
#          '1426', '\xa0', '20', '\xa0', '1446', '1720']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['222', '190', '33', '86', '381', '71', '37', '442', '10', '12',
#          '1484', '\xa0', '20', '\xa0', '1504', '1720'],
#         ['269', '159', '37', '41', '480', '64', '66', '306', '21', '4',
#          '1447', '\xa0', '12', '\xa0', '1459', '1691']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['196', '55', '44', '54', '377', '80', '42', '214', '9', '9',
#          '1080', '\xa0', '7', '\xa0', '1087', '1351'],
#         ['196', '31', '33', '39', '448', '65', '71', '163', '30', '5',
#          '1081', '\xa0', '15', '\xa0', '1096', '1424']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['244', '65', '49', '77', '388', '58', '44', '202', '3', '8',
#          '1138', '\xa0', '16', '\xa0', '1154', '1290'],
#         ['292', '43', '41', '45', '417', '38', '76', '169', '20', '7',
#          '1148', '\xa0', '11', '\xa0', '1159', '1281']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['109', '64', '15', '63', '344', '62', '18', '286', '4', '14',
#          '979', '\xa0', '9', '1', '989', '1217'],
#         ['128', '49', '20', '25', '430', '47', '26', '209', '16', '8',
#          '958', '\xa0', '14', '\xa0', '972', '1231']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['173', '78', '33', '39', '487', '42', '16', '263', '2', '1',
#          '1134', '\xa0', '13', '\xa0', '1147', '1293'],
#         ['184', '53', '28', '25', '550', '48', '42', '206', '13', '9',
#          '1158', '\xa0', '10', '\xa0', '1168', '1346']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['217', '75', '56', '68', '404', '65', '48', '237', '1', '4',
#          '1175', '1', '12', '2', '1190', '1384'],
#         ['252', '43', '39', '47', '447', '65', '69', '168', '25', '8',
#          '1163', '\xa0', '6', '\xa0', '1169', '1383']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['237', '51', '53', '44', '289', '75', '63', '176', '5', '8',
#          '1001', '2', '13', '\xa0', '1016', '1120'],
#         ['240', '35', '47', '33', '312', '49', '80', '125', '33', '2',
#          '956', '\xa0', '6', '\xa0', '962', '1092']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['217', '57', '40', '53', '395', '73', '35', '289', '4', '4',
#          '1167', '\xa0', '17', '1', '1185', '1419'],
#         ['245', '43', '31', '32', '430', '61', '63', '220', '32', '7',
#          '1164', '\xa0', '12', '\xa0', '1176', '1449']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['128', '98', '18', '63', '402', '62', '19', '360', '1', '12',
#          '1163', '\xa0', '20', '1', '1184', '1378'],
#         ['160', '93', '24', '32', '465', '49', '37', '268', '12', '9',
#          '1149', '\xa0', '8', '2', '1159', '1371']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['101', '75', '12', '35', '256', '40', '17', '334', '3', '6',
#          '879', '\xa0', '11', '\xa0', '890', '1034'],
#         ['111', '64', '13', '16', '325', '42', '33', '248', '13', '10',
#          '875', '\xa0', '12', '\xa0', '887', '1053']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['268', '61', '48', '70', '372', '96', '43', '250', '7', '14',
#          '1229', '1', '9', '\xa0', '1239', '1461'],
#         ['283', '39', '38', '28', '404', '66', '91', '179', '36', '12',
#          '1176', '\xa0', '10', '\xa0', '1186', '1432']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['149', '59', '39', '39', '329', '78', '39', '214', '10', '13',
#          '969', '\xa0', '9', '\xa0', '978', '1161'],
#         ['168', '31', '37', '34', '358', '56', '75', '174', '25', '8',
#          '966', '\xa0', '12', '\xa0', '978', '1169']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['279', '100', '69', '93', '405', '74', '72', '252', '7', '13',
#          '1364', '\xa0', '11', '\xa0', '1375', '1506'],
#         ['320', '65', '72', '53', '426', '69', '86', '186', '30', '7',
#          '1314', '\xa0', '13', '1', '1328', '1462']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['228', '56', '53', '57', '299', '93', '32', '189', '2', '8',
#          '1017', '\xa0', '11', '\xa0', '1028', '1253'],
#         ['213', '35', '36', '45', '364', '57', '79', '142', '23', '12',
#          '1006', '\xa0', '13', '\xa0', '1019', '1289']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga'],
#         ['109', '30', '17', '17', '129', '47', '40', '97', '4', '13',
#          '503', '\xa0', '3', '2'],
#         ['70', '23', '11', '12', '123', '23', '49', '50', '24', '5',
#          '390', '\xa0', '12', '\xa0']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['57', '14', '38', '37', '156', '24', '18', '81', '2', '6', '433',
#          '\xa0', '3', '\xa0', '436', '499'],
#         ['55', '11', '27', '19', '138', '22', '29', '58', '9', '1', '369',
#          '\xa0', '\xa0', '\xa0', '369', '421']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['208', '89', '89', '44', '209', '55', '55', '116', '4', '16',
#          '885', '1', '4', '1', '891', '1017'],
#         ['231', '54', '76', '46', '231', '36', '84', '85', '19', '15',
#          '877', '\xa0', '9', '\xa0', '886', '1047']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['112', '50', '50', '27', '288', '86', '51', '210', '6', '27',
#          '907', '1', '11', '1', '920', '1132'],
#         ['115', '24', '36', '13', '340', '56', '81', '122', '27', '30',
#          '844', '\xa0', '15', '\xa0', '859', '1094']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['192', '53', '52', '52', '308', '76', '32', '166', '7', '8',
#          '946', '\xa0', '12', '\xa0', '958', '1140'],
#         ['192', '35', '46', '27', '356', '39', '66', '113', '23', '16',
#          '913', '\xa0', '10', '\xa0', '923', '1124']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['303', '84', '89', '55', '236', '54', '52', '161', '6', '7',
#          '1047', '\xa0', '9', '1', '1057', '1133'],
#         ['315', '63', '78', '62', '201', '44', '71', '121', '27', '5',
#          '987', '\xa0', '6', '\xa0', '993', '1101']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['238', '73', '100', '72', '277', '60', '57', '154', '12', '11',
#          '1054', '\xa0', '6', '1', '1061', '1222'],
#         ['271', '46', '84', '45', '300', '53', '83', '118', '23', '18',
#          '1041', '\xa0', '9', '\xa0', '1050', '1254']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['275', '104', '85', '78', '343', '81', '56', '238', '2', '13',
#          '1275', '\xa0', '12', '\xa0', '1287', '1455'],
#         ['248', '56', '86', '45', '382', '68', '81', '172', '30', '10',
#          '1178', '\xa0', '7', '\xa0', '1185', '1389']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['217', '74', '93', '64', '444', '75', '43', '253', '4', '13',
#          '1280', '\xa0', '8', '\xa0', '1288', '1535'],
#         ['223', '48', '52', '50', '456', '64', '52', '177', '20', '14',
#          '1156', '\xa0', '9', '\xa0', '1165', '1452']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['285', '77', '97', '83', '391', '85', '57', '223', '8', '18',
#          '1324', '1', '14', '1', '1340', '1505'],
#         ['341', '48', '100', '51', '423', '77', '88', '138', '34', '8',
#          '1308', '\xa0', '5', '1', '1314', '1522']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['319', '89', '95', '68', '373', '112', '53', '218', '5', '15',
#          '1347', '\xa0', '6', '\xa0', '1353', '1509'],
#         ['421', '49', '79', '48', '425', '72', '88', '153', '33', '10',
#          '1378', '\xa0', '5', '\xa0', '1383', '1565']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['212', '66', '59', '66', '283', '86', '39', '204', '3', '20',
#          '1038', '\xa0', '9', '1', '1048', '1217'],
#         ['246', '27', '79', '33', '321', '68', '62', '131', '25', '8',
#          '1000', '\xa0', '11', '\xa0', '1011', '1193']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['281', '73', '78', '71', '383', '91', '53', '237', '7', '11',
#          '1285', '\xa0', '16', '1', '1302', '1502'],
#         ['252', '45', '104', '44', '406', '73', '58', '156', '35', '7',
#          '1180', '\xa0', '14', '\xa0', '1194', '1483']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['262', '91', '75', '83', '375', '84', '53', '189', '7', '17',
#          '1236', '\xa0', '10', '\xa0', '1246', '1411'],
#         ['266', '51', '72', '35', '417', '78', '87', '144', '35', '9',
#          '1194', '\xa0', '10', '\xa0', '1204', '1402']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga'],
#         ['63', '42', '30', '21', '73', '32', '26', '47', '8', '11', '353',
#          '\xa0', '5', '\xa0'],
#         ['110', '15', '40', '12', '123', '29', '56', '38', '22', '6',
#          '451', '\xa0', '11', '\xa0']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['127', '60', '37', '64', '283', '39', '22', '361', '1', '14',
#          '1008', '1', '12', '1', '1022', '1145'],
#         ['161', '77', '37', '29', '367', '31', '32', '278', '8', '7',
#          '1027', '\xa0', '11', '\xa0', '1038', '1175']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['145', '57', '35', '70', '458', '81', '26', '301', '3', '8',
#          '1184', '1', '15', '\xa0', '1200', '1305'],
#         ['153', '36', '32', '53', '543', '69', '47', '211', '11', '4',
#          '1159', '\xa0', '12', '\xa0', '1171', '1295']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['33', '13', '8', '8', '497', '69', '15', '83', '1', '9', '736',
#          '\xa0', '10', '\xa0', '746', '1080'],
#         ['32', '8', '6', '7', '470', '47', '25', '65', '5', '17', '682',
#          '\xa0', '4', '\xa0', '686', '1039']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['112', '33', '30', '38', '347', '85', '29', '208', '4', '15',
#          '901', '\xa0', '16', '\xa0', '917', '1229'],
#         ['81', '27', '34', '21', '431', '61', '59', '146', '13', '12',
#          '885', '\xa0', '8', '\xa0', '893', '1234']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['177', '67', '51', '58', '400', '59', '29', '214', '\xa0', '2',
#          '1057', '2', '6', '2', '1067', '1257'],
#         ['203', '55', '56', '55', '417', '51', '44', '172', '15', '4',
#          '1072', '\xa0', '5', '\xa0', '1077', '1342']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['352', '119', '92', '94', '351', '41', '43', '236', '2', '7',
#          '1337', '\xa0', '13', '1', '1351', '1443'],
#         ['374', '87', '100', '48', '374', '39', '77', '153', '13', '8',
#          '1273', '\xa0', '13', '\xa0', '1286', '1394']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['172', '53', '33', '54', '337', '50', '46', '206', '3', '5',
#          '959', '\xa0', '18', '1', '978', '1105'],
#         ['164', '46', '34', '38', '397', '49', '66', '141', '18', '6',
#          '959', '\xa0', '17', '\xa0', '976', '1115']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['291', '98', '64', '76', '311', '42', '50', '162', '3', '9',
#          '1106', '2', '10', '1', '1119', '1216'],
#         ['327', '71', '78', '45', '317', '40', '75', '107', '22', '6',
#          '1088', '\xa0', '13', '1', '1102', '1210']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['251', '91', '73', '65', '507', '46', '22', '346', '2', '15',
#          '1418', '\xa0', '14', '\xa0', '1432', '1578'],
#         ['253', '82', '64', '53', '579', '40', '43', '229', '14', '11',
#          '1368', '\xa0', '8', '\xa0', '1376', '1560']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['200', '66', '65', '68', '432', '36', '26', '287', '4', '7',
#          '1191', '\xa0', '13', '\xa0', '1204', '1341'],
#         ['230', '44', '43', '33', '500', '45', '55', '211', '10', '7',
#          '1178', '\xa0', '10', '\xa0', '1188', '1357']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['84', '87', '14', '58', '176', '53', '17', '228', '1', '6',
#          '724', '\xa0', '8', '\xa0', '732', '840'],
#         ['99', '82', '14', '28', '222', '26', '25', '154', '9', '5',
#          '664', '\xa0', '11', '\xa0', '675', '819']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['92', '82', '17', '27', '228', '30', '17', '229', '1', '5',
#          '728', '\xa0', '13', '\xa0', '741', '828'],
#         ['83', '99', '7', '16', '279', '28', '21', '185', '13', '1',
#          '732', '\xa0', '8', '\xa0', '740', '836']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['155', '136', '34', '68', '300', '57', '10', '441', '5', '12',
#          '1218', '1', '9', '1', '1229', '1434'],
#         ['175', '148', '34', '26', '394', '58', '23', '294', '13', '8',
#          '1173', '\xa0', '14', '\xa0', '1187', '1400']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga'],
#         ['41', '32', '7', '10', '47', '17', '16', '49', '3', '2', '224',
#          '\xa0', '2', '1'],
#         ['56', '12', '18', '10', '60', '20', '27', '37', '11', '1', '252',
#          '\xa0', '2', '\xa0']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['183', '101', '38', '111', '488', '53', '27', '377', '2', '10',
#          '1390', '\xa0', '9', '2', '1401', '1541'],
#         ['210', '105', '45', '45', '570', '46', '48', '261', '12', '7',
#          '1349', '\xa0', '12', '\xa0', '1361', '1524']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['156', '71', '53', '89', '394', '50', '22', '250', '2', '7',
#          '1094', '\xa0', '8', '\xa0', '1102', '1228'],
#         ['178', '69', '45', '42', '451', '46', '33', '178', '8', '8',
#          '1058', '\xa0', '11', '\xa0', '1069', '1234']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['131', '101', '23', '75', '249', '54', '16', '341', '1', '10',
#          '1001', '\xa0', '10', '\xa0', '1011', '1159'],
#         ['151', '128', '26', '41', '293', '38', '24', '229', '13', '8',
#          '951', '\xa0', '5', '\xa0', '956', '1136']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['133', '50', '33', '60', '347', '46', '33', '196', '2', '11',
#          '911', '\xa0', '10', '2', '923', '1073'],
#         ['170', '27', '35', '40', '409', '29', '43', '137', '6', '8',
#          '904', '\xa0', '4', '\xa0', '908', '1063']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['96', '96', '5', '43', '203', '31', '19', '238', '\xa0', '6',
#          '737', '\xa0', '5', '\xa0', '742', '830'],
#         ['107', '106', '12', '35', '242', '31', '19', '161', '8', '2',
#          '723', '\xa0', '3', '\xa0', '726', '816']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['167', '46', '59', '90', '458', '59', '29', '233', '\xa0', '8',
#          '1149', '\xa0', '8', '\xa0', '1157', '1335'],
#         ['157', '34', '63', '50', '477', '37', '43', '150', '9', '4',
#          '1024', '\xa0', '8', '\xa0', '1032', '1238']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['315', '129', '89', '137', '449', '81', '63', '315', '6', '12',
#          '1596', '1', '12', '\xa0', '1609', '1744'],
#         ['344', '110', '95', '77', '506', '40', '95', '235', '33', '15',
#          '1550', '\xa0', '5', '1', '1556', '1726']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['377', '153', '75', '148', '492', '61', '53', '352', '1', '10',
#          '1722', '\xa0', '10', '\xa0', '1732', '1871'],
#         ['365', '116', '42', '87', '515', '50', '69', '245', '14', '5',
#          '1508', '\xa0', '7', '\xa0', '1515', '1666']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['283', '75', '65', '85', '461', '81', '51', '305', '1', '15',
#          '1422', '\xa0', '16', '2', '1440', '1611'],
# ...
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['258', '110', '70', '81', '459', '66', '43', '294', '2', '20',
#          '1403', '\xa0', '22', '\xa0', '1425', '1724'],
#         ['273', '78', '54', '37', '534', '57', '72', '204', '23', '15',
#          '1347', '\xa0', '15', '\xa0', '1362', '1693']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['501', '185', '100', '183', '304', '29', '44', '379', '5', '18',
#          '1748', '\xa0', '13', '\xa0', '1761', '1918'],
#         ['662', '123', '97', '77', '283', '10', '68', '240', '20', '18',
#          '1598', '\xa0', '13', '\xa0', '1611', '1770']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['147', '158', '30', '72', '143', '38', '19', '268', '3', '10',
#          '888', '\xa0', '11', '\xa0', '899', '1026'],
#         ['164', '190', '19', '28', '185', '25', '30', '208', '13', '6',
#          '868', '\xa0', '17', '\xa0', '885', '1048']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['288', '96', '82', '85', '201', '30', '30', '263', '3', '1',
#          '1079', '\xa0', '8', '1', '1088', '1191'],
#         ['\xa0', '\xa0', '\xa0', '\xa0', '\xa0', '\xa0', '\xa0', '\xa0',
#          '\xa0', '\xa0', '\xa0', '\xa0', '\xa0', '\xa0', '\xa0', '\xa0']],
#        dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['149', '52', '40', '48', '241', '60', '23', '272', '1', '6',
#          '892', '1', '6', '1', '900', '1040'],
#         ['201', '60', '31', '20', '302', '40', '52', '182', '18', '12',
#          '918', '\xa0', '11', '\xa0', '929', '1091']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['137', '112', '35', '67', '197', '39', '23', '275', '1', '16',
#          '902', '\xa0', '10', '\xa0', '912', '1070'],
#         ['168', '129', '22', '30', '248', '27', '32', '194', '8', '15',
#          '873', '\xa0', '15', '\xa0', '888', '1062']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['174', '136', '23', '63', '277', '49', '34', '333', '4', '26',
#          '1119', '\xa0', '12', '\xa0', '1131', '1316'],
#         ['224', '143', '23', '43', '317', '45', '52', '226', '16', '17',
#          '1106', '\xa0', '13', '\xa0', '1119', '1321']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['211', '266', '42', '107', '274', '51', '43', '451', '4', '21',
#          '1470', '2', '13', '3', '1488', '1751'],
#         ['280', '269', '35', '51', '326', '30', '69', '329', '22', '18',
#          '1429', '\xa0', '18', '1', '1448', '1743']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga'],
#         ['75', '36', '17', '22', '82', '23', '37', '74', '1', '2', '369',
#          '\xa0', '6', '\xa0'],
#         ['71', '19', '21', '9', '52', '9', '34', '37', '7', '5', '264',
#          '\xa0', '2', '\xa0']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['183', '76', '46', '67', '531', '85', '43', '181', '2', '14',
#          '1228', '\xa0', '19', '\xa0', '1247', '1513'],
#         ['214', '44', '59', '36', '550', '80', '86', '128', '30', '14',
#          '1241', '\xa0', '20', '1', '1262', '1533']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['297', '107', '86', '165', '428', '61', '34', '302', '3', '13',
#          '1496', '\xa0', '11', '\xa0', '1507', '1706'],
#         ['327', '75', '96', '87', '505', '42', '47', '192', '18', '12',
#          '1401', '\xa0', '29', '\xa0', '1430', '1650']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['416', '169', '136', '113', '511', '112', '75', '265', '4', '19',
#          '1820', '2', '15', '1', '1838', '2073'],
#         ['499', '82', '95', '70', '486', '86', '135', '201', '49', '21',
#          '1724', '\xa0', '15', '1', '1740', '2010']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['149', '62', '68', '76', '559', '112', '39', '225', '1', '14',
#          '1305', '3', '11', '\xa0', '1319', '1619'],
#         ['162', '37', '55', '49', '645', '78', '86', '155', '18', '24',
#          '1309', '\xa0', '10', '\xa0', '1319', '1614']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['352', '121', '98', '87', '510', '65', '60', '175', '7', '14',
#          '1489', '1', '9', '1', '1500', '1643'],
#         ['380', '64', '106', '66', '518', '62', '112', '119', '38', '14',
#          '1479', '\xa0', '12', '\xa0', '1491', '1657']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['64', '80', '8', '31', '81', '26', '14', '136', '\xa0', '10',
#          '450', '\xa0', '4', '1', '455', '539'],
#         ['57', '109', '19', '27', '98', '15', '19', '102', '10', '4',
#          '460', '\xa0', '9', '\xa0', '469', '551']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['87', '103', '26', '44', '130', '24', '15', '117', '\xa0', '9',
#          '555', '\xa0', '4', '\xa0', '559', '664'],
#         ['113', '93', '20', '22', '146', '14', '22', '84', '4', '4',
#          '522', '\xa0', '3', '\xa0', '525', '648']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['211', '141', '61', '72', '208', '44', '32', '174', '2', '8',
#          '953', '\xa0', '14', '\xa0', '967', '1059'],
#         ['236', '124', '59', '28', '224', '39', '54', '128', '14', '10',
#          '916', '\xa0', '16', '\xa0', '932', '1038']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['234', '90', '98', '86', '563', '109', '46', '198', '5', '15',
#          '1444', '1', '21', '5', '1471', '1662'],
#         ['242', '44', '70', '41', '555', '101', '100', '143', '14', '12',
#          '1322', '\xa0', '17', '1', '1340', '1539']], dtype='<U38'),
#  array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#          'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#         ['Moderaterna', 'Centerpartiet',
#          'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#          'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#          'Miljöpartiet de gröna', 'Sverigedemokraterna',
#          'Feministiskt initiativ', 'Övriga anmälda partier',
#          'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#          'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#          'Valdeltagande', 'Antal röstberättigade'],
#         ['145', '82', '36', '51', '146', '30', '39', '155', '\xa0', '7',
#          '691', '\xa0', '4', '\xa0', '695', '758'],
#         ['151', '55', '28', '34', '113', '27', '28', '85', '5', '\xa0',
#          '526', '\xa0', '5', '\xa0', '531', '592']], dtype='<U38'),
#  ...]

# %%
np.array(list(TABLES[0][-1].values()))
# Out:
# array([['M', 'C', 'L', 'KD', 'S', 'V', 'MP', 'SD', 'FI', 'ÖVR', '\xa0',
#         'OGEJ', 'BLANK', 'OG', 'VDT', '\xa0'],
#        ['Moderaterna', 'Centerpartiet',
#         'Liberalerna (tidigare Folkpartiet)', 'Kristdemokraterna',
#         'Arbetarepartiet-Socialdemokraterna', 'Vänsterpartiet',
#         'Miljöpartiet de gröna', 'Sverigedemokraterna',
#         'Feministiskt initiativ', 'Övriga anmälda partier',
#         'Giltiga röster', 'Ogiltiga röster - inte anmälda partier',
#         'Ogiltiga röster - blanka', 'Ogiltiga röster - övriga',
#         'Valdeltagande', 'Antal röstberättigade'],
#        ['162', '37', '37', '53', '519', '82', '32', '311', '8', '11',
#         '1252', '\xa0', '13', '\xa0', '1265', '1555'],
#        ['164', '28', '19', '29', '604', '60', '54', '217', '19', '6',
#         '1200', '\xa0', '10', '\xa0', '1210', '1491']], dtype='<U38')

# %%
values_dfs
# Out:
#     Förk.                                   Parti Antal2018 Antal2014
# 0       M                             Moderaterna       162       164
# 1       C                           Centerpartiet        37        28
# 2       L      Liberalerna (tidigare Folkpartiet)        37        19
# 3      KD                       Kristdemokraterna        53        29
# 4       S      Arbetarepartiet-Socialdemokraterna       519       604
# ..    ...                                     ...       ...       ...
# 9     ÖVR                  Övriga anmälda partier         7         6
# 10                                 Giltiga röster       359       219
# 11   OGEJ  Ogiltiga röster - inte anmälda partier
# 12  BLANK                Ogiltiga röster - blanka         1         2
# 13     OG                Ogiltiga röster - övriga
#
# [100558 rows x 4 columns]

# %%
TABLES[0]
# Out:
# ([('riksdagsvalkrets', 'Blekinge län'),
#   ('kommun', 'Karlshamn'),
#   ('valdistrikt', 'Centrala Asarum')],
#  defaultdict(list,
#              {'Förk.': ['M',
#                'C',
#                'L',
#                'KD',
#                'S',
#                'V',
#                'MP',
#                'SD',
#                'FI',
#                'ÖVR',
#                '\xa0',
#                'OGEJ',
#                'BLANK',
#                'OG',
#                'VDT',
#                '\xa0'],
#               'Parti': ['Moderaterna',
#                'Centerpartiet',
#                'Liberalerna (tidigare Folkpartiet)',
#                'Kristdemokraterna',
#                'Arbetarepartiet-Socialdemokraterna',
#                'Vänsterpartiet',
#                'Miljöpartiet de gröna',
#                'Sverigedemokraterna',
#                'Feministiskt initiativ',
#                'Övriga anmälda partier',
#                'Giltiga röster',
#                'Ogiltiga röster - inte anmälda partier',
#                'Ogiltiga röster - blanka',
#                'Ogiltiga röster - övriga',
#                'Valdeltagande',
#                'Antal röstberättigade'],
#               'Antal2018': ['162',
#                '37',
#                '37',
#                '53',
#                '519',
#                '82',
#                '32',
#                '311',
#                '8',
#                '11',
#                '1252',
#                '\xa0',
#                '13',
#                '\xa0',
#                '1265',
#                '1555'],
#               'Antal2014': ['164',
#                '28',
#                '19',
#                '29',
#                '604',
#                '60',
#                '54',
#                '217',
#                '19',
#                '6',
#                '1200',
#                '\xa0',
#                '10',
#                '\xa0',
#                '1210',
#                '1491']}))

# %%
t = parse_table(table)

# %%
pd.DataFrame(t)
# Out:
#     Förk.                                   Parti Antal2018 Antal2014
# 0       M                             Moderaterna      3632      3923
# 1       C                           Centerpartiet      1392      1015
# 2       L      Liberalerna (tidigare Folkpartiet)       727       616
# 3      KD                       Kristdemokraterna      1095       647
# 4       S      Arbetarepartiet-Socialdemokraterna      7073      8114
# 5       V                          Vänsterpartiet      1306      1044
# 6      MP                   Miljöpartiet de gröna       718      1192
# 7      SD                     Sverigedemokraterna      5218      3867
# 8      FI                  Feministiskt initiativ        95       430
# 9     ÖVR                  Övriga anmälda partier       183       144
# 10                                 Giltiga röster     21439     20992
# 11   OGEJ  Ogiltiga röster - inte anmälda partier         5
# 12  BLANK                Ogiltiga röster - blanka       226       218
# 13     OG                Ogiltiga röster - övriga        10         3
# 14    VDT                           Valdeltagande     21680     21213
# 15                          Antal röstberättigade     24694     24702

# %% [markdown]
# Здравствуйте!
# Замечательное решение, очень круто, что вы решили все задачи, включая дополнительные, вы молодец!)
# Ваш код хорошо оформлен и решает поставленные задачи, есть пару рекомендаций, как его можно улучить:
# 1. Посмотрите что-нибудь про аннотацию типов, это очень полезная вещь, которая улучшит качество кода.
# 2. Лучше не использовать конструкции, в которых очень много проверок и дополнительных действий, важно разграничить область ответственность функций, это улучшить читаемость и предотвратит возможные ошибки, например
#
#       - if not input:
#       -  print("Некорректный ввод")
#       -  return None
#       - #Преобразуем ввод в список элементов
#       - lst = input.split(', ')
#       - #Проверка ввода на корректность
#       - try:
#        - #Конвертация элементов в целое число
#         - lst = list(map(int, lst))
#       - except ValueError:
#         - print("Некорректный ввод")
#         - return None
#      -  lst = sorted(lst)
#       - if len(lst) % 2 == 0:
#         - return (lst[len(lst)//2-1]+lst[len(lst)//2])/2
#       - else:
#         - return lst[len(lst)//2]/1``
#
# Лучше разделить на 2 логические части - проверка и вычисление, подумайте как это можно сделать?
# В остальном все хорошо, ставлю максимальный балл, успехов в учебе!)
# Если возникнут вопросы, пишите в пачку.
# Отзыв подготовил ментор Илья Котов.
